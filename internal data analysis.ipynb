# %%
import pandas as pd
import numpy as np
import sqlite3
# !pip install pandas openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
census_data = pd.read_excel('../shared_data_read_only/Data/AfriKids/ExternalReports/GES_EMIS/Census Data.xlsx')
census_data.head()
# Out:
#    RegCode   Region  DstCode         District Academic_Year  Cr_TotSchs_Pub  \
# 0        1  ASHANTI       11     ADANSI NORTH     2010-2011               1
# 1        1  ASHANTI       12     ADANSI SOUTH     2010-2011               0
# 2        1  ASHANTI       13    SEKYERE SOUTH     2010-2011              19
# 3        1  ASHANTI       14  AHAFO ANO NORTH     2010-2011               0
# 4        1  ASHANTI       15  AHAFO ANO SOUTH     2010-2011               2
#
#    Cr_TotSchs_Prv  Kg_TotSchs_Pub  Kg_TotSchs_Prv  Prm_TotSchs_Pub  ...  \
# 0              14              82              25               85  ...
# 1              10              99              30              105  ...
# 2              11              67              19               65  ...
# 3               5              63              11               63  ...
# 4               9              97              17               95  ...
#
# ...

# %%
census_data = pd.read_excel('../shared_data_read_only/Data/AfriKids/InternalData/1. Master Stats 2023.xlsx')
census_data.head()
# Out:
#   Use the + or - at the left of the row numbers to open/close the groups  \
# 0                                            General
# 1                                         Population
# 2                                        Population
# 3                    Percentage of female population
# 4                      Percentage of male population
#
#                     Notes     Ghana       UER Pre-2018 Northern Region  \
# 0  Demographics, AfriKids       NaN       NaN                      NaN
# 1                     NaN       NaN       NaN                      NaN
# 2                     NaN  30832019   1301226                      NaN
# 3                     NaN  0.506992  0.514871                      NaN
# 4                     NaN  0.493008  0.485129                      NaN
#
#         UWR            NR            NER          Sav.R  \
# 0       NaN           NaN            NaN            NaN
# 1       NaN           NaN            NaN            NaN
# ...

# %%
census_data = pd.read_excel('../shared_data_read_only/Data/AfriKids/InternalData/2. Key stats Ghana and Northern Ghana 2021.xlsx')
census_data.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN                                                NaN
# 1         NaN                                        6411.881188
# 2         NaN                                                NaN
# 3         NaN                                 poverty incidence
# 4         NaN  contribution to total (Ghana) population in po...
#
#   to work out "1 in X" statements, divide 100 by the % number given (as a number not a %)  \
# 0                                                NaN
# 1                                              Ghana
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                   Unnamed: 3 Unnamed: 4          Unnamed: 5  \
# 0                        NaN        NaN                 NaN
# 1  Northern Regions combined      Rural  Poorest population
# ...

# %%
import pandas as pd

file_path = '../shared_data_read_only/Data/AfriKids/InternalData/2. Key stats Ghana and Northern Ghana 2021.xlsx'


df = pd.read_excel(file_path, engine='openpyxl')


df
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN                                                NaN
# 1          NaN                                        6411.881188
# 2          NaN                                                NaN
# 3          NaN                                 poverty incidence
# 4          NaN  contribution to total (Ghana) population in po...
# 5          NaN                          extreme poverty incidence
# 6          NaN  contribution to total (Ghana) population in ex...
# 7          NaN                                                age
# 8          NaN                                          education
# 9          NaN                                                NaN
# 10         NaN                                           violence
# 11         NaN                          child marriage - under 18
# 12         NaN                          child marriage - under 15
# ...

# %%
import pandas as pd


file_path = '../shared_data_read_only/Data/AfriKids/InternalData/2023 Key stats inc 21 census.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')


df = pd.read_excel(file_path, sheet_name='POPULATION summary' )
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  Unless specified otherwise, data on all tabs i...
# 1          NaN                                                NaN
# 2          NaN                                            Tab key
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8          NaN                                                NaN
# 9          NaN                                                NaN
# 10         NaN                                                NaN
# 11         NaN                                                NaN
# 12         NaN                                                NaN
#
# ...

# %%
pd.read_excel(file_path, sheet_name='POPULATION summary' )
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                     Basic education
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  https://afrikids.sharepoint.com/:x:/g/EZxBRSr6...
# 15                                                NaN
# ...

# %%
# WE HAVE Ghana Districts Map n Populations data set here for 2020
import pandas as pd


file_path = '../shared_data_read_only/Data/AfriKids/InternalData/Ghana Districts Map and Population 2020.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')

df
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  Ghana Statistical Service 2019: https://www.st...
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                  1
# ..         ...                                                ...
# 92         NaN                                                NaN
# 93         NaN                                                NaN
# 94         NaN                                                NaN
# 95         NaN                                                NaN
# 96         NaN                                                NaN
#
#            Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5         Unnamed: 6  \
# 0                 NaN         NaN         NaN         NaN                NaN
# ...

# %%
import pandas as pd

file_path = '../shared_data_read_only/Data/AfriKids/InternalData/1. Master Stats 2023.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')

df

import matplotlib.pyplot as plt

regions = df.columns[1:]  
population_data = df.loc[df[0] == 'Population']

plt.figure(figsize=(10, 6))
plt.bar(regions, population_data.iloc[0, 1:])
plt.title('Population Distribution by Region')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 12
#       9 import matplotlib.pyplot as plt
# ...
